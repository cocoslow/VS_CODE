# %% [markdown]
# > <font size="4">**제목**</font>
# ```javas
#
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javas
# ![image.png](attachment:image.png)
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javas
# ![image.png](attachment:image.png)
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```st
# (* 38번: 51회 1일차 타이머 반복 회로 *)
#
# // 1. 시작(P0) 및 리셋(P1) 로직
# IF LDP(1, X0) THEN
#     M38 := 1;      // 시작 자기유지
# ELSIF X1 THEN
#     M38 := 0;      // 리셋
# END_IF;
#
# // 2. 15초(150) 반복 타이머 루프
# // T0 접점으로 자기 자신을 리셋하여 무한 반복 (15초 주기)
# OUT_T(M38 AND NOT T0, T0, 150);
#
# // 3. 출력 로직 (비교문 및 MOD 연산 활용)
# Y40 := M38 AND ((T0 MOD 20) < 10);   // 1초 점멸 (1초 온, 1초 오프)
# Y41 := M38 AND (T0 < 150);           // 15초 동안 상시 점등 [cite: 107]
# Y42 := M38 AND ((T0 MOD 40) < 20);   // 2초 점멸 (2초 온, 2초 오프) [cite: 108]
# Y43 := M38 AND ((T0 MOD 40) >= 20);  // 2초 점멸 (2초 오프, 2초 온 - Y42 반전) [cite: 108]
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javas
#
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javas
#
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javas
#
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javas
#
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javas
#
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javas
#
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javas
#
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javas
#
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javas
#
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javas
#
# ```
# ---
