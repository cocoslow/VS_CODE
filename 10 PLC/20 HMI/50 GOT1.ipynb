# %% [markdown]
# > <font size="4">**제목**</font>
# ```javascript
#
# if([w:D0]>0){
# switch([w:D0]){
#  case 160:
#          [w:GD300]=0;
#          break;
#  case 161:
#          [w:GD300]=16;
#          break;
#          }}
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javascript
# if([w:R14471]==1){
#    [w:R14473]=[w:B0000];
#    [w:R14474]=[w:B0010];}
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javascript
# if([w:R14471]==1){
#    [w:R14473]=[w:B0000];
#    [w:R14474]=[w:B0010];}
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javascript
# if([b:GB400]==1){
#    bmov([w:R1201],[w:GD20000],99);
# rst([b:GB400]);}
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javascript
# if(([w:R1205]!=0)&&([w:R27220]!=0))
# {
#     [w:GD702]=8435;
#     [w:R1206]=(([w:GD702]+[w:R1207])*600/[w:R1205])+135;
# }
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javascript
# {
#     [w:GD702]=8900;
#     [w:R1206]=(([w:GD702]+[w:R1207])*600/[w:R1205])+135;
# }
#
# if([w:R1208]!=0)
# {
#    [w:R1209]=((2185-[w:R1207])*600/[w:R1208]);
# }
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javascript
# IF(D0*D1) <= 200 THEN           // D0*D1이 200 이하라면
# D0 := 0;                        // D0에 0을 대입
# END_IF ;
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javascript
# [w:GD200]=[w:GD300]+1;
# [w:GD201]=[w:GD300]+2;
# [w:GD202]=[w:GD300]+3;
# [w:GD203]=[w:GD300]+4;
# [w:GD204]=[w:GD300]+5;
# [w:GD205]=[w:GD300]+6;
# [w:GD206]=[w:GD300]+7;
# [w:GD207]=[w:GD300]+8;
# [w:GD208]=[w:GD300]+9;
# [w:GD209]=[w:GD300]+10;
# [w:GD210]=[w:GD300]+11;
# [w:GD211]=[w:GD300]+12;
# [w:GD212]=[w:GD300]+13;
# [w:GD213]=[w:GD300]+14;
# [w:GD214]=[w:GD300]+15;
# [w:GD215]=[w:GD300]+16;
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javascript
# [w:GD201]=[w:ZR14451]*32-31;
# [w:GD202]=[w:ZR14451]*32-30;
# [w:GD203]=[w:ZR14451]*32-29;
# [w:GD204]=[w:ZR14451]*32-28;
# [w:GD205]=[w:ZR14451]*32-27;
# [w:GD206]=[w:ZR14451]*32-26;
# [w:GD207]=[w:ZR14451]*32-25;
# [w:GD208]=[w:ZR14451]*32-24;
# [w:GD209]=[w:ZR14451]*32-23;
# [w:GD210]=[w:ZR14451]*32-22;
# [w:GD211]=[w:ZR14451]*32-21;
# [w:GD212]=[w:ZR14451]*32-20;
# [w:GD213]=[w:ZR14451]*32-19;
# [w:GD214]=[w:ZR14451]*32-18;
# [w:GD215]=[w:ZR14451]*32-17;
# [w:GD216]=[w:ZR14451]*32-16;
# [w:GD217]=[w:ZR14451]*32-15;
# [w:GD218]=[w:ZR14451]*32-14;
# [w:GD219]=[w:ZR14451]*32-13;
# [w:GD220]=[w:ZR14451]*32-12;
# [w:GD221]=[w:ZR14451]*32-11;
# [w:GD222]=[w:ZR14451]*32-10;
# [w:GD223]=[w:ZR14451]*32-9;
# [w:GD224]=[w:ZR14451]*32-8;
# [w:GD225]=[w:ZR14451]*32-7;
# [w:GD226]=[w:ZR14451]*32-6;
# [w:GD227]=[w:ZR14451]*32-5;
# [w:GD228]=[w:ZR14451]*32-4;
# [w:GD229]=[w:ZR14451]*32-3;
# [w:GD230]=[w:ZR14451]*32-2;
# [w:GD231]=[w:ZR14451]*32-1;
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javascript
# [w:GD1] = ([w:D100] - 1) * 10 + 1;
# [w:GD2] = ([w:D100] - 1) * 10 + 2;
# [w:GD3] = ([w:D100] - 1) * 10 + 3;
# [w:GD4] = ([w:D100] - 1) * 10 + 4;
# [w:GD5] = ([w:D100] - 1) * 10 + 5;
# [w:GD6] = ([w:D100] - 1) * 10 + 6;
# [w:GD7] = ([w:D100] - 1) * 10 + 7;
# [w:GD8] = ([w:D100] - 1) * 10 + 8;
# [w:GD9] = ([w:D100] - 1) * 10 + 9;
# [w:GD10] = ([w:D100] - 1) * 10 + 10;
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javascript
# [w:GD5001]=[w:GD2001]*600/[w:R5001];
# [w:GD3501]=[w:GD5001]+[w:GD3001];
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javascript
# if([w:D0]>0){
# swich([w:D0]){
# case 160:
#    [w:GD300]=0;
#    break;
# case 161:
#    [w:GD300]=16;
#    break;
#    }}
#
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javascript
# if(([b:M3])&&([b:SM412]))
# {
# [b:GB310] = 1 ;
# }
# else
# {
# [b:GB310] = 0 ;
# }
#
# ///////////////////////////////////////////////////////////////////
#
# if(([b:M3]) {
# [b:GB310] = 1 ;
# }
# else{
# [b:GB310] = 0 ;
# }
#
# if([b:X100]==1) {[w:D0]=100;} //X100이 켜질 경우 D0이 100임.
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javascript
# switch ([w:ZR10088]){
#  case 1:
#  [b:GB300] = 1 ;
# break;  case 2:
#  [b:GB301] = 1 ;
# break;
# }
#
# // ZR10088 == 1 이면 GB300 ON 유지
# ZR10088 == 2 이면 GB301 ON 유지
# 2여도 GB300이 OFF되지않는다
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javascript
#
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javascript
#
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javascript
#
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javascript
#
# ```
# ---

# %% [markdown]
# > <font size="4">**제목**</font>
# ```javascript
#
# ```
# ---
# ```javascript
#
# ```
# ---
